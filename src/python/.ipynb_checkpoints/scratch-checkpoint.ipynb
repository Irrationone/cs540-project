# %% [markdown]
# ## Data loading
#
# We'll begin by doing PCA on our train + test datasets to see how separable our classes are.

# %%
# %matplotlib inline

import sys
import numpy as np
import pandas as pd
import zipfile
from sklearn.decomposition import PCA, KernelPCA
from sklearn import preprocessing
import matplotlib.pyplot as plt
import seaborn as sns

zf_train = zipfile.ZipFile('../../data/train.csv.zip')
train = pd.DataFrame.from_csv(zf_train.open('train.csv'))

zf_test = zipfile.ZipFile('../../data/test.csv.zip')
test = pd.DataFrame.from_csv(zf_test.open('test.csv'))


## Dimensions of train set
ntrain,dtrain = train.shape

## Dimensions of test set
ntest, dtest = test.shape

# %% [markdown]
# ## Columns with zero variance
#
# Columns with zero variance are labeled as 1; columns with variation are labeled as 0.

# %%
a = np.all(train == train.iloc[0,], axis = 0)[0:dtrain-1]
b = np.all(test == test.iloc[0,], axis = 0)
identicals = np.column_stack((a,b))

ax = sns.heatmap(identicals, xticklabels=['Train', 'Test'], yticklabels=False)
ax.set(xlabel='Dataset', ylabel='Feature')
plt.show()

# %%
train = pd.concat([train.iloc[:,~a], train.iloc[:,len(train.columns)-1]], axis=1)
test = test.iloc[:,~a]

# %% [markdown]
# This is good news -- columns with 0 variance in the test dataset are a subset of those in the train dataset. If this was **not** true, our training set would not be sufficient for classification of our test set.

# %% [markdown]
# ## Principal components analysis

# %%
def pca_plot(X, targets, title):
    target_names = np.unique(targets)
    pca = PCA(n_components = 2)
    X_r = pca.fit(X).transform(X)
    X_scaled = preprocessing.scale(X_r)
    print('explained variance ratio (first two components): %s'
          % str(pca.explained_variance_ratio_))

    plt.figure()
    for c, i, target_name in zip("rb", [0, 1], target_names):
        plt.scatter(X_scaled[np.where(targets == i),0], X_scaled[np.where(targets == i),1], c=c, label=target_name)
    plt.legend()
    plt.title(title)

def kernel_pca(X, targets, title, kernel, **kwargs):
    kpca = KernelPCA(kernel=kernel, fit_inverse_transform=True, **kwargs)
    X_kpca = kpca.fit_transform(X)
    X_back = kpca.inverse_transform(X_kpca)
    pca_plot(X_back, targets, title)

# %%
X = train.drop(['TARGET'], axis=1)
Xtest = test

## Standardize sets together
Xtotal = X.append(Xtest)
Xtotal_scaled = preprocessing.scale(Xtotal)
X_scaled,Xtest_scaled = np.split(Xtotal_scaled, [ntrain])

targets = np.array(train.TARGET)
pca_plot(X_scaled, targets, title='PCA of training set')

eggs = np.zeros((ntest,1))
pca_plot(Xtest_scaled, eggs, title='PCA of test set')
# Out:
# explained variance ratio (first two components): [ 0.07887261  0.05153247]
# explained variance ratio (first two components): [ 0.08508405  0.05360071]
# /Users/allen/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/data.py:153: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %%
features = ['var3', 'var15', 'imp_ent_var16_ult1', 'imp_op_var39_comer_ult3', 
'imp_op_var41_comer_ult1', 'imp_op_var41_comer_ult3', 'imp_op_var41_efect_ult1', 
'imp_op_var41_efect_ult3', 'imp_op_var41_ult1', 'imp_op_var39_ult1', 'ind_var8_0', 
'ind_var30_0', 'ind_var30', 'num_op_var41_hace2', 'num_op_var41_ult3', 
'num_var37_med_ult2', 'saldo_var5', 'saldo_var8', 'saldo_var26', 'saldo_var30', 
'saldo_var37', 'saldo_var42', 'imp_var43_emit_ult1', 'imp_trans_var37_ult1', 
'num_var22_hace2', 'num_var22_hace3', 'num_var22_ult1', 'num_var22_ult3',
'num_med_var45_ult3', 'num_meses_var5_ult3', 'num_meses_var39_vig_ult3',
'num_op_var39_comer_ult1', 'num_op_var41_efect_ult3', 'num_op_var39_efect_ult1',
'num_var43_recib_ult1', 'num_var45_hace2', 'num_var45_hace3', 'num_var45_ult1',
'num_var45_ult3', 'saldo_medio_var5_hace2', 'saldo_medio_var5_hace3', 
'saldo_medio_var5_ult1', 'saldo_medio_var5_ult3', 'saldo_medio_var8_hace2',
'saldo_medio_var8_ult1', 'saldo_medio_var8_ult3', 'saldo_medio_var12_ult3',
'saldo_medio_var13_corto_hace2', 'var38']

def subset_features(mat, features, columns):
    df = pd.DataFrame(mat, columns=columns)
    subset = df[features]
    return(subset)

X_train_subset = subset_features(X_train, features, X.columns)
X_valid_subset = subset_features(X_valid, features, X.columns)


tsne = manifold.TSNE(n_components=2, init='pca', random_state=1, n_iter=200, verbose=20)

X_tsne = tsne.fit_transform(X_valid)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 15204
# [t-SNE] Computed conditional probabilities for sample 2000 / 15204
# [t-SNE] Computed conditional probabilities for sample 3000 / 15204
# [t-SNE] Computed conditional probabilities for sample 4000 / 15204
# [t-SNE] Computed conditional probabilities for sample 5000 / 15204
# [t-SNE] Computed conditional probabilities for sample 6000 / 15204
# [t-SNE] Computed conditional probabilities for sample 7000 / 15204
# [t-SNE] Computed conditional probabilities for sample 8000 / 15204
# [t-SNE] Computed conditional probabilities for sample 9000 / 15204
# [t-SNE] Computed conditional probabilities for sample 10000 / 15204
# [t-SNE] Computed conditional probabilities for sample 11000 / 15204
# [t-SNE] Computed conditional probabilities for sample 12000 / 15204
# [t-SNE] Computed conditional probabilities for sample 13000 / 15204
# [t-SNE] Computed conditional probabilities for sample 14000 / 15204
# [t-SNE] Computed conditional probabilities for sample 15000 / 15204
# [t-SNE] Computed conditional probabilities for sample 15204 / 15204
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Iteration 10: error = 25.5530019, gradient norm = 0.0055433
# [t-SNE] Iteration 20: error = 24.6781999, gradient norm = 0.0048661
# [t-SNE] Iteration 30: error = 24.1086618, gradient norm = 0.0049513
# [t-SNE] Iteration 40: error = 23.7360350, gradient norm = 0.0048439
# [t-SNE] Iteration 50: error = 23.5180340, gradient norm = 0.0047047
# [t-SNE] Iteration 60: error = 21.8424172, gradient norm = 0.0037110
# [t-SNE] Iteration 70: error = 20.6420197, gradient norm = 0.0029011
# [t-SNE] Iteration 80: error = 20.1279334, gradient norm = 0.0022552
# [t-SNE] Iteration 90: error = 19.8873372, gradient norm = 0.0020607
# [t-SNE] Iteration 100: error = 19.7505161, gradient norm = 0.0020525
# [t-SNE] Error after 100 iterations with early exaggeration: 19.750516
# [t-SNE] Iteration 110: error = 3.3999584, gradient norm = 0.0021946
# [t-SNE] Iteration 120: error = 3.2629547, gradient norm = 0.0019568
# [t-SNE] Iteration 130: error = 3.1879883, gradient norm = 0.0018419
# [t-SNE] Iteration 140: error = 3.1470815, gradient norm = 0.0017821
# [t-SNE] Iteration 150: error = 3.1240126, gradient norm = 0.0017496
# [t-SNE] Iteration 160: error = 3.1106765, gradient norm = 0.0017312
# [t-SNE] Iteration 170: error = 3.1028527, gradient norm = 0.0017205
# [t-SNE] Iteration 180: error = 3.0982240, gradient norm = 0.0017142
# [t-SNE] Iteration 190: error = 3.0954722, gradient norm = 0.0017105
# [t-SNE] Iteration 200: error = 3.0938315, gradient norm = 0.0017083
# [t-SNE] Error after 200 iterations: 3.093831

# %% [markdown]
# ## Kernel PCA
#
# This is very, very slow on the full dataset, and should not be run.

# %%
#kernel_pca(X, targets, title='Kernel PCA of training set', kernel='poly', degree=3)

# %% [markdown]
# ## Create validation set
#
# Since we have no test set to evaluate our performance on, we must create a validation set from a subset of our training set. This set will not be used for training and is NOT to be confused with the validation set used for cross-validation.

# %%
from sklearn import cross_validation

sss = cross_validation.StratifiedShuffleSplit(targets, 1, test_size=0.2, random_state=0)
(train_index,valid_index) = list(sss)[0]

X_train = X_scaled[train_index,]
X_valid = X_scaled[valid_index,]
y_train = targets[train_index]
y_valid = targets[valid_index]

print(X_train.shape)
print(X_valid.shape)
# Out:
# (60816, 335)
# (15204, 335)

# %%
##t-SNE visualization

# %%
from sklearn import manifold
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import normalize

# %%
features = ['var3', 'var15', 'imp_ent_var16_ult1', 'imp_op_var39_comer_ult3', 
'imp_op_var41_comer_ult1', 'imp_op_var41_comer_ult3', 'imp_op_var41_efect_ult1', 
'imp_op_var41_efect_ult3', 'imp_op_var41_ult1', 'imp_op_var39_ult1', 'ind_var8_0', 
'ind_var30_0', 'ind_var30', 'num_op_var41_hace2', 'num_op_var41_ult3', 
'num_var37_med_ult2', 'saldo_var5', 'saldo_var8', 'saldo_var26', 'saldo_var30', 
'saldo_var37', 'saldo_var42', 'imp_var43_emit_ult1', 'imp_trans_var37_ult1', 
'num_var22_hace2', 'num_var22_hace3', 'num_var22_ult1', 'num_var22_ult3',
'num_med_var45_ult3', 'num_meses_var5_ult3', 'num_meses_var39_vig_ult3',
'num_op_var39_comer_ult1', 'num_op_var41_efect_ult3', 'num_op_var39_efect_ult1',
'num_var43_recib_ult1', 'num_var45_hace2', 'num_var45_hace3', 'num_var45_ult1',
'num_var45_ult3', 'saldo_medio_var5_hace2', 'saldo_medio_var5_hace3', 
'saldo_medio_var5_ult1', 'saldo_medio_var5_ult3', 'saldo_medio_var8_hace2',
'saldo_medio_var8_ult1', 'saldo_medio_var8_ult3', 'saldo_medio_var12_ult3',
'saldo_medio_var13_corto_hace2', 'var38']

def subset_features(mat, features, columns):
    df = pd.DataFrame(mat, columns=columns)
    subset = df[features]
    return(subset)

X_train_subset = subset_features(X_train, features, X.columns)
X_valid_subset = subset_features(X_valid, features, X.columns)


tsne = manifold.TSNE(n_components=2, init='pca', random_state=1, n_iter=1000, verbose=20)

X_tsne = tsne.fit_transform(X_valid_subset)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 15204
# [t-SNE] Computed conditional probabilities for sample 2000 / 15204
# [t-SNE] Computed conditional probabilities for sample 3000 / 15204
# [t-SNE] Computed conditional probabilities for sample 4000 / 15204
# [t-SNE] Computed conditional probabilities for sample 5000 / 15204
# [t-SNE] Computed conditional probabilities for sample 6000 / 15204
# [t-SNE] Computed conditional probabilities for sample 7000 / 15204
# [t-SNE] Computed conditional probabilities for sample 8000 / 15204
# [t-SNE] Computed conditional probabilities for sample 9000 / 15204
# [t-SNE] Computed conditional probabilities for sample 10000 / 15204
# [t-SNE] Computed conditional probabilities for sample 11000 / 15204
# [t-SNE] Computed conditional probabilities for sample 12000 / 15204
# [t-SNE] Computed conditional probabilities for sample 13000 / 15204
# [t-SNE] Computed conditional probabilities for sample 14000 / 15204
# [t-SNE] Computed conditional probabilities for sample 15000 / 15204
# [t-SNE] Computed conditional probabilities for sample 15204 / 15204
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Iteration 10: error = 25.2323017, gradient norm = 0.0063885
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-246-1ba87c9aa5d1> in <module>()
#      25 tsne = manifold.TSNE(n_components=2, init='pca', random_state=1, n_iter=1000, verbose=20)
#      26
# ---> 27 X_tsne = tsne.fit_transform(X_valid_subset)
#
# /Users/allen/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in fit_transform(self, X, y)
#     522             Embedding of the training data in low-dimensional space.
#     523         """
# --> 524         self.fit(X)
#     525         return self.embedding_
#
# /Users/allen/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in fit(self, X, y)
#     459
#     460         self.embedding_ = self._tsne(P, alpha, n_samples, random_state,
# --> 461                                      X_embedded=X_embedded)
#     462
#     463     def _tsne(self, P, alpha, n_samples, random_state, X_embedded=None):
#
# /Users/allen/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _tsne(self, P, alpha, n_samples, random_state, X_embedded)
#     484             min_grad_norm=0.0, min_error_diff=0.0,
#     485             learning_rate=self.learning_rate, verbose=self.verbose,
# --> 486             args=[P, alpha, n_samples, self.n_components])
#     487         params, error, it = _gradient_descent(
#     488             _kl_divergence, params, it=it + 1, n_iter=100, momentum=0.8,
#
# /Users/allen/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _gradient_descent(objective, p0, it, n_iter, n_iter_without_progress, momentum, learning_rate, min_gain, min_grad_norm, min_error_diff, verbose, args)
#     182
#     183     for i in range(it, n_iter):
# --> 184         new_error, grad = objective(p, *args)
#     185         error_diff = np.abs(new_error - error)
#     186         error = new_error
#
# /Users/allen/anaconda/lib/python2.7/site-packages/sklearn/manifold/t_sne.pyc in _kl_divergence(params, P, alpha, n_samples, n_components)
#     104     PQd = squareform((P - Q) * n)
#     105     for i in range(n_samples):
# --> 106         np.dot(_ravel(PQd[i]), X_embedded[i] - X_embedded, out=grad[i])
#     107     grad = grad.ravel()
#     108     c = 2.0 * (alpha + 1.0) / alpha
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.scatter(X_tsne[np.where(y_valid == 0), 0],
                   X_tsne[np.where(y_valid == 0), 1],
                   marker='x', color='g',
                   linewidth='1', alpha=0.8, label='Happy')
plt.scatter(X_tsne[np.where(y_valid == 1), 0],
                   X_tsne[np.where(y_valid == 1), 1],
                   marker='v', color='r',
                   linewidth='1', alpha=0.8, label='Unhappy')

plt.xlabel('Dim 1')
plt.ylabel('Dim 2')
plt.title('T-SNE on 10% train samples')
plt.legend(loc='best')
plt.savefig('1.png')
plt.show()

# %% [markdown]
# ## Utilities

# %%
## Computes AUC based on validation set
def compute_auc(preds):
    fpr, tpr, thresholds = metrics.roc_curve(y_valid, preds, pos_label=1)
    return metrics.auc(fpr, tpr)

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

def logreg_cv(X_train, y_train, c, fold):
    logreg = LogisticRegression(penalty='l2', dual=False, max_iter=100, C=c)
    cv_scores = cross_validation.cross_val_score(logreg, X_train, y_train, cv=fold)
    return np.mean(cv_scores)

# %%
## Too slow

#lambdas = np.power(float(2), range(-10,11))

#result = [logreg_cv(X_train, y_train, c, 3) for c in lambdas]

# %% [markdown]
# As we can see, logistic regression with an L2-regularizer is way too slow on this dataset.

# %% [markdown]
# ## XGBoost
#
# ### Logistic regression

# %%
import xgboost as xgb
import re
import StringIO

def fpreproc(dtrain, dtest, param):
    label = dtrain.get_label()
    ratio = float(np.sum(label == 0)) / np.sum(label==1)
    param['scale_pos_weight'] = ratio
    return (dtrain, dtest, param)

def parse_string(cv_string):
    a = cv_string.split("\t")[1]
    return re.search('(?<=:)[0-9.]+', a).group(0)



lambdas = np.power(float(2), range(10,20))

# %% [markdown]
# We use cross-validation to select the optimal value of lambda and the number of rounds. We can also select the optimal values of eta, max_depth, etc.
#
# Since the evaluation function used in the Kaggle competition is the AUC, we use that here as well.
#
# For time purposes, I've set the maximum num_round to 20. This can and should be increased for better results though.

# %%
def xgb_cv_lambda(X_train, y_train, l, max_round=10):
    dtrain = xgb.DMatrix(X_train, y_train)
    
    param = {'bst:max_depth':2, 'bst:eta':1, 'silent':1, 'objective':'binary:logistic', 'lambda':l }
    param['nthread'] = 4
    param['eval_metric'] = 'auc'
    num_round = max_round
    
    ## verbose_eval=False isn't available in my version of xgboost (0.4.0)
    actualstderr = sys.stderr
    sys.stderr = StringIO.StringIO()
    results = xgb.cv( param, dtrain, num_round, 3, fpreproc = fpreproc)
    sys.stderr = actualstderr
    sys.stderr.flush()
    
    test_errors = [float(i) for i in [parse_string(c) for c in results]]
    return [np.max(test_errors), np.argmax(test_errors)]


cv_errors = [xgb_cv_lambda(X_train, y_train, l, 20) for l in lambdas]

#bst.save_model('0001.model')

#ypred = bst.predict(dtest,ntree_limit=bst.best_ntree_limit)
#sum(y_valid == ypred)/float(len(y_pred))

# %% [markdown]
# **NOTE:** The best value of lambda selected is at the boundary (2^10 = 1024). When I have time, I should re-run cross-validation with a set of higher lambda values.
#
# Having found our best parameter values, we train with those to get the desired model. Testing this out on our validation (**not test**) set, we get an error of:

# %%
index = np.argmax([x[0] for x in cv_errors])
bestlambda = lambdas[index]
bestnrounds = cv_errors[index][1]+1

# %%
def train_and_predict(X_train, y_train, X_test, y_test, l, existing_prediction = False, preprocess = True, n=20):
    dtrain = xgb.DMatrix(X_train, y_train)
    dtest = xgb.DMatrix(X_valid, y_valid)
    
    param = {'bst:max_depth':5, 'bst:eta':0.05, 'silent':0, 'objective':'binary:logistic', 'lambda':l }
    param['nthread'] = 4
    param['eval_metric'] = 'auc'

    if preprocess == True:
        dtrain, dtest, param = fpreproc(dtrain, dtest, param)
        
    evallist  = [(dtest,'eval'), (dtrain,'train')]
    
    ## Boost from existing prediction
    if existing_prediction == True:
        actualstderr = sys.stderr
        sys.stderr = StringIO.StringIO()
        bst = xgb.train(param, dtrain, n, evallist)
        sys.stderr = actualstderr
        sys.stderr.flush()
        
        tmp_train = bst.predict(dtrain, output_margin=True)
        tmp_test = bst.predict(dtest, output_margin=True)
        dtrain.set_base_margin(tmp_train)
        dtest.set_base_margin(tmp_test)
        bst = xgb.train(param, dtrain, n, evallist)
    else:
        bst = xgb.train(param, dtrain, n, evallist)
    return(bst)

# %%
bst = train_and_predict(X_train, y_train, X_valid, y_valid, bestlambda, existing_prediction=10, preprocess=True, n=100)
# Out:
# [0]	eval-auc:0.774407	train-auc:0.805115
# [1]	eval-auc:0.776743	train-auc:0.805973
# [2]	eval-auc:0.775472	train-auc:0.805350
# [3]	eval-auc:0.776363	train-auc:0.806698
# [4]	eval-auc:0.781212	train-auc:0.810256
# [5]	eval-auc:0.790803	train-auc:0.818863
# [6]	eval-auc:0.791662	train-auc:0.819612
# [7]	eval-auc:0.792272	train-auc:0.820018
# [8]	eval-auc:0.791817	train-auc:0.820233
# [9]	eval-auc:0.791598	train-auc:0.820296
# [10]	eval-auc:0.793665	train-auc:0.822248
# [11]	eval-auc:0.793319	train-auc:0.822856
# [12]	eval-auc:0.796347	train-auc:0.826526
# [13]	eval-auc:0.798265	train-auc:0.828253
# [14]	eval-auc:0.798187	train-auc:0.828081
# [15]	eval-auc:0.801153	train-auc:0.830962
# [16]	eval-auc:0.801832	train-auc:0.831803
# [17]	eval-auc:0.802253	train-auc:0.832154
# [18]	eval-auc:0.803890	train-auc:0.833995
# [19]	eval-auc:0.803665	train-auc:0.834390
# [20]	eval-auc:0.803830	train-auc:0.834295
# [21]	eval-auc:0.804393	train-auc:0.834681
# [22]	eval-auc:0.805004	train-auc:0.835010
# [23]	eval-auc:0.805941	train-auc:0.835748
# [24]	eval-auc:0.805737	train-auc:0.835722
# [25]	eval-auc:0.806137	train-auc:0.835849
# [26]	eval-auc:0.807285	train-auc:0.836681
# [27]	eval-auc:0.807714	train-auc:0.836996
# [28]	eval-auc:0.807696	train-auc:0.837530
# [29]	eval-auc:0.807155	train-auc:0.837624
# [30]	eval-auc:0.808361	train-auc:0.838240
# [31]	eval-auc:0.808501	train-auc:0.838386
# [32]	eval-auc:0.808637	train-auc:0.838658
# [33]	eval-auc:0.809309	train-auc:0.839081
# [34]	eval-auc:0.809957	train-auc:0.839541
# [35]	eval-auc:0.810427	train-auc:0.839845
# [36]	eval-auc:0.810554	train-auc:0.840493
# [37]	eval-auc:0.810940	train-auc:0.840799
# [38]	eval-auc:0.810671	train-auc:0.840815
# [39]	eval-auc:0.811410	train-auc:0.841333
# [40]	eval-auc:0.812225	train-auc:0.841710
# [41]	eval-auc:0.812292	train-auc:0.841779
# [42]	eval-auc:0.812675	train-auc:0.842029
# [43]	eval-auc:0.812784	train-auc:0.842192
# [44]	eval-auc:0.812963	train-auc:0.842428
# [45]	eval-auc:0.813226	train-auc:0.842556
# [46]	eval-auc:0.813994	train-auc:0.842911
# [47]	eval-auc:0.814091	train-auc:0.842958
# [48]	eval-auc:0.814163	train-auc:0.843149
# [49]	eval-auc:0.814340	train-auc:0.843281
# [50]	eval-auc:0.814359	train-auc:0.843544
# [51]	eval-auc:0.814568	train-auc:0.843664
# [52]	eval-auc:0.814567	train-auc:0.843727
# [53]	eval-auc:0.814859	train-auc:0.844040
# [54]	eval-auc:0.814955	train-auc:0.844075
# [55]	eval-auc:0.815019	train-auc:0.844278
# [56]	eval-auc:0.815062	train-auc:0.844389
# [57]	eval-auc:0.815367	train-auc:0.844772
# [58]	eval-auc:0.815521	train-auc:0.844929
# [59]	eval-auc:0.815664	train-auc:0.845053
# [60]	eval-auc:0.815719	train-auc:0.845146
# [61]	eval-auc:0.817008	train-auc:0.846353
# [62]	eval-auc:0.817200	train-auc:0.846466
# [63]	eval-auc:0.817169	train-auc:0.846435
# [64]	eval-auc:0.817185	train-auc:0.846608
# [65]	eval-auc:0.817349	train-auc:0.846839
# [66]	eval-auc:0.817427	train-auc:0.846938
# [67]	eval-auc:0.817493	train-auc:0.847020
# [68]	eval-auc:0.817504	train-auc:0.847181
# [69]	eval-auc:0.817562	train-auc:0.847343
# [70]	eval-auc:0.817612	train-auc:0.847430
# [71]	eval-auc:0.817669	train-auc:0.847550
# [72]	eval-auc:0.817688	train-auc:0.847798
# [73]	eval-auc:0.817863	train-auc:0.847896
# [74]	eval-auc:0.817923	train-auc:0.848069
# [75]	eval-auc:0.818079	train-auc:0.848220
# [76]	eval-auc:0.818177	train-auc:0.848228
# [77]	eval-auc:0.818269	train-auc:0.848354
# [78]	eval-auc:0.818668	train-auc:0.848779
# [79]	eval-auc:0.818728	train-auc:0.848929
# [80]	eval-auc:0.818951	train-auc:0.849155
# [81]	eval-auc:0.819069	train-auc:0.849325
# [82]	eval-auc:0.819126	train-auc:0.849461
# [83]	eval-auc:0.819285	train-auc:0.849636
# [84]	eval-auc:0.819519	train-auc:0.849820
# [85]	eval-auc:0.819536	train-auc:0.849998
# [86]	eval-auc:0.819574	train-auc:0.850149
# [87]	eval-auc:0.819694	train-auc:0.850285
# [88]	eval-auc:0.819668	train-auc:0.850441
# [89]	eval-auc:0.819713	train-auc:0.850573
# [90]	eval-auc:0.819778	train-auc:0.850651
# [91]	eval-auc:0.819765	train-auc:0.850713
# [92]	eval-auc:0.819738	train-auc:0.850818
# [93]	eval-auc:0.819795	train-auc:0.850956
# [94]	eval-auc:0.819936	train-auc:0.851085
# [95]	eval-auc:0.819971	train-auc:0.851169
# [96]	eval-auc:0.820028	train-auc:0.851277
# [97]	eval-auc:0.820156	train-auc:0.851398
# [98]	eval-auc:0.820223	train-auc:0.851499
# [99]	eval-auc:0.820270	train-auc:0.851615

# %%
dtest = xgb.DMatrix(X_valid, y_valid)

## Dummy for now; run CV again to get the real number
bestnrounds = 200

xg_pred = bst.predict(dtest,ntree_limit=bestnrounds)

compute_auc(xg_pred)
# Out:
# 0.82026952344852411

# %% [markdown]
# So we achieve a validation set AUC of 0.82 with minimal tuning.

# %% [markdown]
# ### Extreme value regression

# %%
def extreme_objective(preds, dtrain):
    labels = dtrain.get_label()
    e = np.exp(preds)
    p = 1.0 / (1.0 - np.exp(-e))
    grad = labels*(1-p)*e + (1-labels)*e
    hess = labels*np.power(e,2)*(p-1)*p + (1-labels)*e
    return grad, hess

def train_and_predict_extreme(X_train, y_train, X_test, y_test, l, existing_prediction = False, preprocess = True, n=20):
    dtrain = xgb.DMatrix(X_train, y_train)
    dtest = xgb.DMatrix(X_valid, y_valid)
    
    param = {'bst:max_depth':3, 'bst:eta':1, 'silent':1, 'lambda':l }
    param['nthread'] = 4
    param['eval_metric'] = 'auc'
    
    def evalerror(preds, dtrain):
        labels = dtrain.get_label()
        # return a pair metric_name, result
        # since preds are margin(before logistic transformation, cutoff at 0)
        return 'error', float(sum(labels != (preds > 0.0))) / len(labels)

    if preprocess == True:
        dtrain, dtest, param = fpreproc(dtrain, dtest, param)
        
    evallist  = [(dtest,'eval'), (dtrain,'train')]
    
    ## Boost from existing prediction
    if existing_prediction == True:
        actualstderr = sys.stderr
        sys.stderr = StringIO.StringIO()
        bst = xgb.train(param, dtrain, n, evallist, extreme_objective)
        sys.stderr = actualstderr
        sys.stderr.flush()
        
        tmp_train = bst.predict(dtrain, output_margin=True)
        tmp_test = bst.predict(dtest, output_margin=True)
        dtrain.set_base_margin(tmp_train)
        dtest.set_base_margin(tmp_test)
        bst = xgb.train(param, dtrain, n, evallist, extreme_objective)
    else:
        bst = xgb.train(param, dtrain, n, evallist, extreme_objective)
    return bst;

# %%
train_and_predict_extreme(X_train, y_train, X_valid, y_valid, bestlambda, existing_prediction=True, preprocess=False, n=100)
# Out:
# [0]	eval-auc:0.822621	train-auc:0.859285
# [1]	eval-auc:0.822671	train-auc:0.859371
# [2]	eval-auc:0.822727	train-auc:0.859453
# [3]	eval-auc:0.822752	train-auc:0.859492
# [4]	eval-auc:0.822720	train-auc:0.859548
# [5]	eval-auc:0.822691	train-auc:0.859641
# [6]	eval-auc:0.822619	train-auc:0.859693
# [7]	eval-auc:0.822586	train-auc:0.859815
# [8]	eval-auc:0.822566	train-auc:0.859955
# [9]	eval-auc:0.822620	train-auc:0.860165
# [10]	eval-auc:0.822636	train-auc:0.860333
# [11]	eval-auc:0.822778	train-auc:0.860418
# [12]	eval-auc:0.822785	train-auc:0.860507
# [13]	eval-auc:0.822824	train-auc:0.860510
# [14]	eval-auc:0.822755	train-auc:0.860574
# [15]	eval-auc:0.822777	train-auc:0.860679
# [16]	eval-auc:0.822784	train-auc:0.860777
# [17]	eval-auc:0.822735	train-auc:0.860934
# [18]	eval-auc:0.822884	train-auc:0.861087
# [19]	eval-auc:0.822843	train-auc:0.861198
# [20]	eval-auc:0.823048	train-auc:0.861325
# [21]	eval-auc:0.823067	train-auc:0.861417
# [22]	eval-auc:0.823114	train-auc:0.861415
# [23]	eval-auc:0.822995	train-auc:0.861512
# [24]	eval-auc:0.822970	train-auc:0.861589
# [25]	eval-auc:0.822991	train-auc:0.861635
# [26]	eval-auc:0.822985	train-auc:0.861718
# [27]	eval-auc:0.822953	train-auc:0.861763
# [28]	eval-auc:0.822977	train-auc:0.861807
# [29]	eval-auc:0.822837	train-auc:0.861913
# [30]	eval-auc:0.822855	train-auc:0.861987
# [31]	eval-auc:0.822832	train-auc:0.861999
# [32]	eval-auc:0.822838	train-auc:0.862037
# [33]	eval-auc:0.822765	train-auc:0.862129
# [34]	eval-auc:0.822820	train-auc:0.862219
# [35]	eval-auc:0.822795	train-auc:0.862296
# [36]	eval-auc:0.822869	train-auc:0.862327
# [37]	eval-auc:0.822860	train-auc:0.862440
# [38]	eval-auc:0.822812	train-auc:0.862509
# [39]	eval-auc:0.822776	train-auc:0.862617
# [40]	eval-auc:0.822563	train-auc:0.862766
# [41]	eval-auc:0.822548	train-auc:0.862809
# [42]	eval-auc:0.822651	train-auc:0.862926
# [43]	eval-auc:0.822823	train-auc:0.863084
# [44]	eval-auc:0.822868	train-auc:0.863215
# [45]	eval-auc:0.822743	train-auc:0.863355
# [46]	eval-auc:0.822810	train-auc:0.863434
# [47]	eval-auc:0.822714	train-auc:0.863479
# [48]	eval-auc:0.822747	train-auc:0.863498
# [49]	eval-auc:0.822701	train-auc:0.863574
# [50]	eval-auc:0.822756	train-auc:0.863608
# [51]	eval-auc:0.822703	train-auc:0.863664
# [52]	eval-auc:0.822676	train-auc:0.863672
# [53]	eval-auc:0.822582	train-auc:0.863756
# [54]	eval-auc:0.822521	train-auc:0.863846
# [55]	eval-auc:0.822540	train-auc:0.863923
# [56]	eval-auc:0.822613	train-auc:0.864019
# [57]	eval-auc:0.822615	train-auc:0.864034
# [58]	eval-auc:0.822529	train-auc:0.864099
# [59]	eval-auc:0.822489	train-auc:0.864149
# [60]	eval-auc:0.822446	train-auc:0.864280
# [61]	eval-auc:0.822578	train-auc:0.864279
# [62]	eval-auc:0.822505	train-auc:0.864320
# [63]	eval-auc:0.822553	train-auc:0.864464
# [64]	eval-auc:0.822495	train-auc:0.864595
# [65]	eval-auc:0.822537	train-auc:0.864714
# [66]	eval-auc:0.822452	train-auc:0.864789
# [67]	eval-auc:0.822481	train-auc:0.864876
# [68]	eval-auc:0.822530	train-auc:0.864983
# [69]	eval-auc:0.822613	train-auc:0.865055
# [70]	eval-auc:0.822567	train-auc:0.865100
# [71]	eval-auc:0.822545	train-auc:0.865129
# [72]	eval-auc:0.822605	train-auc:0.865159
# [73]	eval-auc:0.822672	train-auc:0.865197
# [74]	eval-auc:0.822545	train-auc:0.865276
# [75]	eval-auc:0.822536	train-auc:0.865404
# [76]	eval-auc:0.822650	train-auc:0.865470
# [77]	eval-auc:0.822712	train-auc:0.865562
# [78]	eval-auc:0.822644	train-auc:0.865675
# [79]	eval-auc:0.822604	train-auc:0.865743
# [80]	eval-auc:0.822700	train-auc:0.865776
# [81]	eval-auc:0.822759	train-auc:0.865838
# [82]	eval-auc:0.822761	train-auc:0.865903
# [83]	eval-auc:0.822806	train-auc:0.865988
# [84]	eval-auc:0.822701	train-auc:0.866060
# [85]	eval-auc:0.822668	train-auc:0.866191
# [86]	eval-auc:0.822689	train-auc:0.866296
# [87]	eval-auc:0.822672	train-auc:0.866320
# [88]	eval-auc:0.822639	train-auc:0.866377
# [89]	eval-auc:0.822600	train-auc:0.866438
# [90]	eval-auc:0.822547	train-auc:0.866500
# [91]	eval-auc:0.822577	train-auc:0.866561
# [92]	eval-auc:0.822474	train-auc:0.866655
# [93]	eval-auc:0.822378	train-auc:0.866703
# [94]	eval-auc:0.822300	train-auc:0.866756
# [95]	eval-auc:0.822496	train-auc:0.866834
# [96]	eval-auc:0.822600	train-auc:0.866944
# [97]	eval-auc:0.822482	train-auc:0.866981
# [98]	eval-auc:0.822406	train-auc:0.867082
# [99]	eval-auc:0.822350	train-auc:0.867133

# %% [markdown]
# As we can see, extreme value regression can sometimes perform a little better than logistic regression, but not by much.

# %% [markdown]
# ## Extra trees classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn import ensemble
from sklearn import metrics

extc = ExtraTreesClassifier(n_estimators=100,max_features= 30,criterion= 'entropy',min_samples_split= 2,
                            max_depth= 30, min_samples_leaf= 2, n_jobs = -1) 

extc.fit(X_train_subset,y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='entropy',
#            max_depth=30, max_features=30, max_leaf_nodes=None,
#            min_samples_leaf=2, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
extc_pred = extc.predict_proba(X_valid_subset)
extc_pred = [x[1] for x in extc_pred]

compute_auc(extc_pred)
# Out:
# 0.80651196463780273

# %% [markdown]
# This works pretty well, even when using only a subset of the features! Probably worth including in the ensemble.
#
# ### Sigmoid correction
#
# To make this work even better, we're going to calibrate it (sigmoidally). See the **calibration** section below for more information on what this is doing.

# %%
extc_sigmoid = CalibratedClassifierCV(extc, cv=2, method='sigmoid')
extc_sigmoid.fit(X_train_subset,y_train)
extc_sigmoid_pred = extc_sigmoid.predict_proba(X_valid_subset)[:, 1]

compute_auc(extc_sigmoid_pred)
# Out:
# 0.80942912293905955

# %% [markdown]
# ## Ensemble methods
#
# Ultimately, the classifers likely to perform best will be ensemble methods.
#
# Things to try out in an ensemble:
# * Gradient boosting (as above)
# * Extra trees classifier
# * Random forests
# * Other logistic/SVM classifiers (sofia-ml, vowpal-rabbit)
#
# Try stacking these models with logistic regression as the "combiner".

# %% [markdown]
# ### Visualizing correlations
#
# It helps by first visualizing what the correlations are between the extra trees and XGBoost classifiers. This will give us an idea of whether it will be helpful to use both within the same ensemble (if they are well correlated, using them together won't improve our results by much).

# %%
plt.scatter(xg_pred,extc_sigmoid_pred, c = y_valid)
plt.legend(loc=3)
plt.xlabel("XGBoost probability")
plt.ylabel("Extra trees classifier probability (sigmoid calibrated)")

# %% [markdown]
# ### Calibration

# %% [markdown]
# Here we'll show a plot of what calibration is actually doing. Note how the curves below do not reach the diagonal (which would be ideal). This gives us an idea about how reliable our probabilities are.

# %%
from sklearn import datasets
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (brier_score_loss, precision_score, recall_score,
                             f1_score)
from sklearn.calibration import CalibratedClassifierCV, calibration_curve

def plot_calibration_curve(preds, name, fig_index):
    """Plot calibration curve for est w/o and with calibration. """

    fig = plt.figure(fig_index, figsize=(10, 10))
    ax1 = plt.subplot2grid((3, 1), (0, 0), rowspan=2)
    ax2 = plt.subplot2grid((3, 1), (2, 0))

    ax1.plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
    for prob_pos, nm in zip(preds, name):

        clf_score = brier_score_loss(y_valid, prob_pos, pos_label=y_train.max())

        fraction_of_positives, mean_predicted_value = \
            calibration_curve(y_valid, prob_pos, n_bins=10)

        ax1.plot(mean_predicted_value, fraction_of_positives, "s-",
                 label="%s (%1.3f)" % (nm, clf_score))

        ax2.hist(prob_pos, range=(0, 1), bins=10, label=nm,
                 histtype="step", lw=2)

    ax1.set_ylabel("Fraction of positives")
    ax1.set_ylim([-0.05, 1.05])
    ax1.legend(loc="lower right")
    ax1.set_title('Calibration plots  (reliability curve)')

    ax2.set_xlabel("Mean predicted value")
    ax2.set_ylabel("Count")
    ax2.legend(loc="upper center", ncol=2)

    plt.tight_layout()

# %%
preds = [xg_pred, np.array(extc_pred), extc_sigmoid_pred]
plot_calibration_curve(preds, ["XGBoost", "Extra Trees", "Sigmoid corrected extra trees"], 1)

# %% [markdown]
# ### Calibrating XGBoost
#
# We can do the same for XGBoost, but we'll need to define a wrapper class to work with.

# %%
class XGBoostClassifier():
    def __init__(self, num_boost_round=10, **params):
        self.clf = None
        self.num_boost_round = num_boost_round
        self.params = params
        self.params.update({'lambda': 4096})
        self.params.update({'objective': 'binary:logistic'})

    def fit(self, X, y, num_boost_round=None):
        num_boost_round = num_boost_round or self.num_boost_round
        dtrain = xgb.DMatrix(X, y)
        self.clf = xgb.train(params=self.params, dtrain=dtrain, num_boost_round=num_boost_round)

    def predict(self, X):
        num2label = dict((i, label) for label, i in self.label2num.items())
        Y = self.predict_proba(X, num_boost_round)
        y = np.argmax(Y, axis=1)
        return np.array([num2label[i] for i in y])

    def predict_proba(self, X):
        dtest = xgb.DMatrix(X)
        preds = self.clf.predict(dtest)
        return np.vstack((1-preds, preds)).T

    def score(self, X, y):
        Y = self.predict_proba(X)
        return 1 / logloss(y, Y)

    def get_params(self, deep=True):
        return self.params

    def set_params(self, **params):
        if 'num_boost_round' in params:
            self.num_boost_round = params.pop('num_boost_round')
        if 'objective' in params:
            del params['objective']
        self.params.update(params)
        return self

# %%
clf = XGBoostClassifier(
        eval_metric = 'auc',
        nthread = 4,
        eta = 1,
        num_boost_round = 20,
        max_depth = 3,
        silent = 1,
        )

clf_sigmoid = CalibratedClassifierCV(clf, cv=2, method='sigmoid')
clf_sigmoid.fit(X_train,y_train)
xg_sigmoid_pred = clf_sigmoid.predict_proba(X_valid)[:,1]

compute_auc(xg_sigmoid_pred)
# Out:
# 0.7869283368545974

# %% [markdown]
# Alarmingly, this actually does worse than not calibrating! Hence, sigmoid calibration is probably not very good for XGBoost (not completely surprising given the shape of the calibration curve), so we won't use it.

# %% [markdown]
# ### Combining predictions into an ensemble
#
# Here, we need to find robust methods for combining predictions (probabilities) from different ensemble methods.
#
# #### Arithmetic mean
#
# We'll start with a simple method -- using the arithmetic mean.

# %%
mean_preds = [np.mean([a,b]) for a,b in zip(xg_pred, extc_sigmoid_pred)]
compute_auc(mean_preds)
# Out:
# 0.82130753034786563

# %% [markdown]
# This does marginally better than either of the methods alone -- but nothing to write home about.
#
# #### Mean rank
#
# **TODO:** Combine predictions from SVM, Random Forest using the mean. I don't expect this to work well though, given that the mean isn't a robust measure when dealing with probabilities.
#
# **TODO:** Find some better way to combine means from different models in an ensemble. Something that allows weighting, or works by a voting scheme, perhaps?

# %%
from scipy.stats import rankdata

mean_ranks = [np.mean([a,b]) for a,b in zip(rankdata(xg_pred), rankdata(extc_sigmoid_pred))]
scaled_ranks = mean_ranks/max(mean_ranks)

compute_auc(scaled_ranks)
# Out:
# 0.82245599860939267

# %% [markdown]
# Import random forest code. Plot correlations with that.
